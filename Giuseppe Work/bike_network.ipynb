# %%
import osmnx as ox
import pandas as pd

# %%
bike_lanes = ox.graph_from_point((37.87221747622785, -122.25893682309217), custom_filter='["cycleway"]')
ox.plot_graph(bike_lanes)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)
