# %% [markdown]
# # OSMnx features demo
#
# Author: [Geoff Boeing](https://geoffboeing.com/)
#
# Get street networks and other spatial data anywhere in the world from OpenStreetMap then analyze and visualize them.
#
# More info:
#
#   - [Overview of OSMnx](http://geoffboeing.com/2016/11/osmnx-python-street-networks/)
#   - [Documentation and install instructions](https://osmnx.readthedocs.io)
#   - [Examples, demos, tutorials](https://github.com/gboeing/osmnx-examples)
#   - [Journal article and citation info](http://geoffboeing.com/publications/osmnx-complex-street-networks/)
#   - [GitHub repo](https://github.com/gboeing/osmnx)
#
# This notebook provides a quick tour of some of OSMnx's key features including how to:
#
#   - download/model street networks
#   - calculate stats
#   - visualize centrality
#   - impute speeds/travel times and calculate shortest paths
#   - attach and visualize elevation data and edge grades
#   - download/model other infrastructure types
#   - download points of interest data

# %%
pip install osmnx==1.1.1
# Out:
# Requirement already satisfied: osmnx==1.1.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (1.1.1)
# Requirement already satisfied: pandas>=1.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (1.4.2)
# Requirement already satisfied: Rtree>=0.9 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (0.9.7)
# Requirement already satisfied: numpy>=1.19 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (1.21.5)
# Requirement already satisfied: Shapely>=1.7 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (1.8.4)
# Requirement already satisfied: geopandas>=0.9 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (0.10.2)
# Requirement already satisfied: matplotlib>=3.3 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (3.5.1)
# Requirement already satisfied: requests>=2.25 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (2.27.1)
# Requirement already satisfied: networkx>=2.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (2.7.1)
# Requirement already satisfied: pyproj>=2.6 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from osmnx==1.1.1) (3.4.0)
# Requirement already satisfied: fiona>=1.8 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas>=0.9->osmnx==1.1.1) (1.8.21)
# Requirement already satisfied: pillow>=6.2.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.1.1) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.1.1) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.1.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.1.1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.1.1) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.1.1) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.1.1) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1->osmnx==1.1.1) (2021.3)
# Requirement already satisfied: certifi in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pyproj>=2.6->osmnx==1.1.1) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25->osmnx==1.1.1) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25->osmnx==1.1.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25->osmnx==1.1.1) (3.3)
# Requirement already satisfied: munch in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx==1.1.1) (2.5.0)
# Requirement already satisfied: setuptools in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx==1.1.1) (61.2.0)
# Requirement already satisfied: click>=4.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx==1.1.1) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx==1.1.1) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx==1.1.1) (1.1.1)
# Requirement already satisfied: six>=1.7 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx==1.1.1) (1.16.0)
# Requirement already satisfied: attrs>=17 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx==1.1.1) (21.4.0)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install geopandas==0.10.2
# Out:
# Requirement already satisfied: geopandas==0.10.2 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (0.10.2)
# Requirement already satisfied: pandas>=0.25.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas==0.10.2) (1.4.2)
# Requirement already satisfied: fiona>=1.8 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas==0.10.2) (1.8.21)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas==0.10.2) (3.4.0)
# Requirement already satisfied: shapely>=1.6 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas==0.10.2) (1.8.4)
# Requirement already satisfied: certifi in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas==0.10.2) (2021.10.8)
# Requirement already satisfied: six>=1.7 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas==0.10.2) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas==0.10.2) (1.1.1)
# Requirement already satisfied: munch in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas==0.10.2) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas==0.10.2) (0.7.2)
# Requirement already satisfied: attrs>=17 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas==0.10.2) (21.4.0)
# Requirement already satisfied: setuptools in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas==0.10.2) (61.2.0)
# Requirement already satisfied: click>=4.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas==0.10.2) (8.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas==0.10.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas==0.10.2) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas==0.10.2) (1.21.5)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import networkx as nx
import osmnx as ox
import geopandas

# %matplotlib inline
ox.__version__
# Out:
# '1.1.1'

# %%
print(geopandas.__version__)
# Out:
# 0.10.2

# %% [markdown]
# ## Working with street networks

# %%
# download/model a street network for some city then visualize it
G = ox.graph_from_place("Piedmont, California, USA", network_type="drive",simplify=True)
fig, ax = ox.plot_graph(G)
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %% [markdown]
# OSMnx geocodes the query "Piedmont, California, USA" to retrieve the place boundaries of that city from the Nominatim API, retrieves the drivable street network data within those boundaries from the Overpass API, constructs a graph model, then simplifies/corrects its topology such that nodes represent intersections and dead-ends and edges represent the street segments linking them. All of this is discussed in detail in the documentation and these examples.
#
# OSMnx models all networks as NetworkX `MultiDiGraph` objects. You can convert to:
#   - undirected MultiGraphs
#   - DiGraphs without (possible) parallel edges
#   - GeoPandas node/edge GeoDataFrames

# %%
# convert your MultiDiGraph to an undirected MultiGraph
M = ox.utils_graph.get_undirected(G)

# convert your MultiDiGraph to a DiGraph without parallel edges
D = ox.utils_graph.get_digraph(G)

# %%
# you can convert your graph to node and edge GeoPandas GeoDataFrames
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)
gdf_nodes.head()
# Out:
#                   y           x  street_count highway  \
# osmid
# 53017091  37.826250 -122.247604             3     NaN
# 53018397  37.824224 -122.247194             3     NaN
# 53018399  37.824918 -122.246080             3     NaN
# 53018402  37.825406 -122.245317             3     NaN
# 53018404  37.825948 -122.244467             3     NaN
#
#                              geometry
# osmid
# 53017091  POINT (-122.24760 37.82625)
# 53018397  POINT (-122.24719 37.82422)
# 53018399  POINT (-122.24608 37.82492)
# 53018402  POINT (-122.24532 37.82541)
# 53018404  POINT (-122.24447 37.82595)

# %%
gdf_edges.head()
# Out:
#                            osmid          name      highway  oneway   length  \
# u        v        key
# 53017091 53064327 0      6345781   Rose Avenue  residential   False  231.335
#          53075599 0      6345781   Rose Avenue  residential   False  121.114
# 53018397 53097980 0    196739937  Linda Avenue     tertiary   False  100.767
#          53018399 0      6327298   Lake Avenue  residential   False  124.622
#          53018411 0    196739937  Linda Avenue     tertiary   False   37.803
#
#                                                                 geometry  \
# u        v        key
# 53017091 53064327 0    LINESTRING (-122.24760 37.82625, -122.24551 37...
#          53075599 0    LINESTRING (-122.24760 37.82625, -122.24770 37...
# 53018397 53097980 0    LINESTRING (-122.24719 37.82422, -122.24777 37...
#          53018399 0    LINESTRING (-122.24719 37.82422, -122.24712 37...
#          53018411 0    LINESTRING (-122.24719 37.82422, -122.24713 37...
#
#                       lanes maxspeed bridge junction
# u        v        key
# 53017091 53064327 0     NaN      NaN    NaN      NaN
#          53075599 0     NaN      NaN    NaN      NaN
# 53018397 53097980 0     NaN      NaN    NaN      NaN
#          53018399 0     NaN      NaN    NaN      NaN
#          53018411 0     NaN      NaN    NaN      NaN

# %% [markdown]
# You can create a graph from node/edge GeoDataFrames, as long as gdf_nodes is indexed by osmid and gdf_edges is multi-indexed by u, v, key (following normal MultiDiGraph structure). This allows you to load graph node/edge shapefiles or GeoPackage layers as GeoDataFrames then convert to a MultiDiGraph for graph analytics.

# %%
# convert node/edge GeoPandas GeoDataFrames to a NetworkX MultiDiGraph
G2 = ox.graph_from_gdfs(gdf_nodes, gdf_edges, graph_attrs=G.graph)

# %% [markdown]
# ## Basic street network stats

# %%
# what sized area does our network cover in square meters?
G_proj = ox.project_graph(G)
nodes_proj = ox.graph_to_gdfs(G_proj, edges=False)
graph_area_m = nodes_proj.unary_union.convex_hull.area
graph_area_m
# Out:
# 4215057.944939512

# %%
# show some basic stats about the network
ox.basic_stats(G_proj, area=graph_area_m, clean_int_tol=15)
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/simplification.py:423: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   return gpd.GeoSeries(list(merged), crs=G.graph["crs"])
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/simplification.py:423: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   return gpd.GeoSeries(list(merged), crs=G.graph["crs"])
# {'n': 348,
#  'm': 940,
#  'k_avg': 5.402298850574713,
#  'edge_length_total': 113089.6010000001,
#  'edge_length_avg': 120.30808617021287,
#  'streets_per_node_avg': 2.9597701149425286,
#  'streets_per_node_counts': {0: 0, 1: 34, 2: 0, 3: 264, 4: 47, 5: 2, 6: 1},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.09770114942528736,
#   2: 0.0,
#   3: 0.7586206896551724,
#   4: 0.13505747126436782,
#   5: 0.005747126436781609,
#   6: 0.0028735632183908046},
#  'intersection_count': 314,
#  'street_length_total': 58501.06400000002,
#  'street_segment_count': 492,
#  'street_length_avg': 118.9046016260163,
#  'circuity_avg': 1.1124746222399648,
#  'self_loop_proportion': 0.006097560975609756,
#  'clean_intersection_count': 266,
#  'node_density_km': 82.56114258590434,
#  'intersection_density_km': 74.49482405739644,
#  'edge_density_km': 26829.904233172525,
#  'street_density_km': 13879.065190606658,
#  'clean_intersection_density_km': 63.10708025244412}

# %% [markdown]
# stats documentation: https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.stats

# %%
# save graph to disk as geopackage (for GIS) or graphml file (for gephi etc)
ox.save_graph_geopackage(G, filepath="./data/mynetwork.gpkg")
ox.save_graphml(G, filepath="./data/mynetwork.graphml")

# %% [markdown]
# ## Visualize street centrality
#
# Here we plot the street network and color its edges (streets) by their relative closeness centrality.

# %%
# convert graph to line graph so edges become nodes and vice versa
edge_centrality = nx.closeness_centrality(nx.line_graph(G))
nx.set_edge_attributes(G, edge_centrality, "edge_centrality")

# %%
# color edges in original graph with closeness centralities from line graph
ec = ox.plot.get_edge_colors_by_attr(G, "edge_centrality", cmap="inferno")
fig, ax = ox.plot_graph(G, edge_color=ec, edge_linewidth=2, node_size=0)

# %% [markdown]
# ## Routing

# %%
# impute missing edge speeds and calculate edge travel times with the speed module
G = ox.speed.add_edge_speeds(G)
G = ox.speed.add_edge_travel_times(G)

# %%
# get the nearest network nodes to two lat/lng points with the distance module
orig = ox.distance.nearest_nodes(G, X=-122.245846, Y=37.828903)
dest = ox.distance.nearest_nodes(G, X=-122.215006, Y=37.812303)

# %%
# find the shortest path between nodes, minimizing travel time, then plot it
route = ox.shortest_path(G, orig, dest, weight="travel_time")
fig, ax = ox.plot_graph_route(G, route, node_size=0)

# %%
# how long is our route in meters?
edge_lengths = ox.utils_graph.get_route_edge_attributes(G, route, "length")
round(sum(edge_lengths))
# Out:
# 4759

# %%
# how far is it between these two nodes as the crow flies?
# use OSMnx's vectorized great-circle distance (haversine) function
orig_x = G.nodes[orig]["x"]
orig_y = G.nodes[orig]["y"]
dest_x = G.nodes[dest]["x"]
dest_y = G.nodes[dest]["y"]
round(ox.distance.great_circle_vec(orig_y, orig_x, dest_y, dest_x))
# Out:
# 3124

# %% [markdown]
# You can add elevation attributes to your graph's nodes automatically with the `elevation` module, using either local raster files or the Google Maps Elevation API.

# %%
# add elevation to nodes automatically, calculate edge grades, plot network
# you need a google elevation api key to run this cell!
try:
    #from keys import google_elevation_api_key
    google_elevation_api_key='AIzaSyC34x3dNYkcg4W_yXKbXr9eUb2eZs1-ldE'
    G = ox.elevation.add_node_elevations_google(G, api_key=google_elevation_api_key)
    G = ox.elevation.add_edge_grades(G)
    nc = ox.plot.get_node_colors_by_attr(G, "elevation", cmap="plasma")
    fig, ax = ox.plot_graph(G, node_color=nc, node_size=20, edge_linewidth=2, edge_color="#333")
except ImportError:
    print("You need a google_elevation_api_key to run this cell.")

# %% [markdown]
# Nodes are colored from lowest elevation (dark blue) to highest (bright yellow).
#
# Example: create [elevation-based](12-node-elevations-edge-grades.ipynb) impedance functions to route around hills.

# %% [markdown]
# ## Get networks other ways
#
# make queries less ambiguous to help the geocoder out, if it's not finding what you're looking for

# %%
# you can make query an unambiguous dict to help the geocoder find it
place = {"city": "San Francisco", "state": "California", "country": "USA"}
G = ox.graph_from_place(place, network_type="drive", truncate_by_edge=True)
fig, ax = ox.plot_graph(G, figsize=(10, 10), node_size=0, edge_color="y", edge_linewidth=0.2)
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %%
# you can get networks anywhere in the world
G = ox.graph_from_place("Sinalunga, Italy", network_type="all")
fig, ax = ox.plot_graph(G, node_size=0, edge_linewidth=0.5)
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %%
# or get network by address, coordinates, bounding box, or any custom polygon
# ...useful when OSM just doesn't already have a polygon for the place you want
davis_hall = (37.8745698,-122.2602781)
one_mile = 1609 #meters
G = ox.graph_from_point(davis_hall, dist=one_mile, network_type='drive')
fig, ax = ox.plot_graph(G, node_size=0)
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %% [markdown]
# Examples of [getting networks](01-overview-osmnx.ipynb) by coordinates, bounding box, or any custom polygon shape.

# %% [markdown]
# ## Get other networked infrastructure types
#
# ...like rail or electric grids or even the canals of Venice and Amsterdam, using the `custom_filter` parameter: [see more examples](08-custom-filters-infrastructure.ipynb).

# %%
# get NY subway rail network
G = ox.graph_from_place(
    "New York, New York, USA",
    retain_all=False,
    truncate_by_edge=True,
    simplify=True,
    custom_filter='["railway"~"subway"]',
)

fig, ax = ox.plot_graph(G, node_size=0, edge_color="w", edge_linewidth=0.2)
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %% [markdown]
# ## Get any geospatial entities' geometries and attributes
#
# Use the `geometries` module to download entities, such as local amenities, points of interest, or building footprints, and turn them into a GeoDataFrame: [see docs](https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.geometries). For more usage examples of downloading geospatial objects from OSM, see [this notebook](16-download-osm-geospatial-entities.ipynb).

# %%
# get all building footprints in some neighborhood
place = "Berkeley, California"
tags = {"building": True}
gdf = ox.geometries_from_place(place, tags)
gdf.shape
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:

# %%
fig, ax = ox.plot_footprints(gdf, figsize=(3, 3))
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %% [markdown]
# See the other notebooks for more examples of visualization with OSMnx.

# %%
# get all parks and bus stops in some neighborhood
tags = {"leisure": "park", "highway": "bus_stop"}
gdf = ox.geometries_from_place(place, tags)
gdf.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [56], in <cell line: 3>()
#       1 # get all parks and bus stops in some neighborhood
#       2 tags = {"leisure": "park", "highway": "bus_stop"}
# ----> 3 gdf = ox.geometries_from_place(place, tags)
#       4 gdf.shape
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/osmnx/geometries.py:217, in geometries_from_place(query, tags, which_result, buffer_dist)
#     213 # create a GeoDataFrame with the spatial boundaries of the place(s)
#     214 if isinstance(query, (str, dict)):
#     215     # if it is a string (place name) or dict (structured place query),
#     216     # then it is a single place
# --> 217     gdf_place = geocoder.geocode_to_gdf(
#     218         query, which_result=which_result, buffer_dist=buffer_dist
#     219     )
#     220 elif isinstance(query, list):
#     221     # if it is a list, it contains multiple places to get
#     222     gdf_place = geocoder.geocode_to_gdf(query, buffer_dist=buffer_dist)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/osmnx/geocoder.py:110, in geocode_to_gdf(query, which_result, by_osmid, buffer_dist)
#     108 gdf = gpd.GeoDataFrame()
#     109 for q, wr in zip(query, which_result):
# --> 110     gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
#     112 # reset GeoDataFrame index and set its CRS
#     113 gdf = gdf.reset_index(drop=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/osmnx/geocoder.py:166, in _geocode_query_to_gdf(query, which_result, by_osmid)
#     162     result = results[0]
#     164 elif which_result is None:
#     165     # else, if which_result=None, auto-select the first (Multi)Polygon
# --> 166     result = _get_first_polygon(results, query)
#     168 elif len(results) >= which_result:
#     169     # else, if we got at least which_result results, choose that one
#     170     result = results[which_result - 1]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/osmnx/geocoder.py:230, in _get_first_polygon(results, query)
#     227         return result
#     229 # if we never found a polygon, throw an error
# --> 230 raise ValueError(f'Nominatim could not geocode query "{query}" to polygonal boundaries')
#
# ValueError: Nominatim could not geocode query "Bunker Hill, Los Angeles, California" to polygonal boundaries

# %%
fig, ax = ox.plot_footprints(gdf, figsize=(3, 3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 fig, ax = ox.plot_footprints(gdf, figsize=(3, 3))
#
# NameError: name 'gdf' is not defined
